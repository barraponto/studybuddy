# %%
from settings import Settings

settings = Settings()

# %%
from agents.studybuddy import StudyBuddyAgent

agent = StudyBuddyAgent(settings)

# %%
agent.generate_question("choice", "easy", "Peruvian modern history")
# Out:
# ChoiceQuestion(question='Which of the following events marked the end of the Spanish colonial period in Peru?', choices=['Battle of Angamos', 'Battle of Ayacucho', 'Battle of Junin', 'Battle of Arica'], answer='Battle of Ayacucho')

# %%
agent.generate_question("fill", "easy", "Brazilian folklore")
# Out:
# FillInTheBlankQuestion(question='Brazilian folklore tells the story of the _______________, a mythical creature that can control the weather.', answer='Boi-Bumbá')
